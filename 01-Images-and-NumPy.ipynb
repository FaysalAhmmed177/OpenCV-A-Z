# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('opencv/data/dog.45.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=425x320 at 0x26115A91948>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (320, 425, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (320, 425, 3)

# %%
plt.imshow(pic_red[:,:,0])

# %%
plt.imshow(pic_red[:,:,2],cmap = 'gray')

# %%
plt.imshow(pic_red[:,:,2])

# %%
pic_red[:,:,1].shape
# Out:
# (320, 425)

# %%
pic_red[:,:,1] = 0
pic_red[:,:,2] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (320, 425, 3)
